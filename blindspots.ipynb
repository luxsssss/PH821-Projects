# %%
pip install pycbc
# Out:
# Requirement already satisfied: pycbc in ./name/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: numpy>=1.16.0 in ./name/lib/python3.12/site-packages (from pycbc) (2.1.2)
# Requirement already satisfied: cython>=0.29 in ./name/lib/python3.12/site-packages (from pycbc) (3.0.11)
# Requirement already satisfied: scipy>=0.16.0 in ./name/lib/python3.12/site-packages (from pycbc) (1.14.1)
# Requirement already satisfied: astropy!=4.0.5,!=4.2.1,>=2.0.3 in ./name/lib/python3.12/site-packages (from pycbc) (6.1.4)
# Requirement already satisfied: matplotlib>=1.5.1 in ./name/lib/python3.12/site-packages (from pycbc) (3.9.2)
# Requirement already satisfied: mpld3>=0.3 in ./name/lib/python3.12/site-packages (from pycbc) (0.5.10)
# Requirement already satisfied: pillow in ./name/lib/python3.12/site-packages (from pycbc) (11.0.0)
# Requirement already satisfied: h5py!=3.7.0,>=3.0.0 in ./name/lib/python3.12/site-packages (from pycbc) (3.12.1)
# Requirement already satisfied: jinja2 in ./name/lib/python3.12/site-packages (from pycbc) (3.1.4)
# Requirement already satisfied: Mako>=1.0.1 in ./name/lib/python3.12/site-packages (from pycbc) (1.3.6)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in ./name/lib/python3.12/site-packages (from pycbc) (4.12.3)
# Requirement already satisfied: tqdm in ./name/lib/python3.12/site-packages (from pycbc) (4.66.6)
# Requirement already satisfied: setuptools in ./name/lib/python3.12/site-packages (from pycbc) (75.3.0)
# Requirement already satisfied: gwdatafind in ./name/lib/python3.12/site-packages (from pycbc) (1.2.0)
# Requirement already satisfied: pegasus-wms.api>=5.0.8 in ./name/lib/python3.12/site-packages (from pycbc) (5.0.8)
# Requirement already satisfied: python-ligo-lw>=1.7.0 in ./name/lib/python3.12/site-packages (from pycbc) (1.8.3)
# Requirement already satisfied: ligo-segments in ./name/lib/python3.12/site-packages (from pycbc) (1.4.0)
# Requirement already satisfied: lalsuite!=7.2 in ./name/lib/python3.12/site-packages (from pycbc) (7.23)
# Requirement already satisfied: lscsoft-glue>=1.59.3 in ./name/lib/python3.12/site-packages (from pycbc) (4.0.0)
# Requirement already satisfied: pykerr in ./name/lib/python3.12/site-packages (from pycbc) (0.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in ./name/lib/python3.12/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in ./name/lib/python3.12/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (0.2024.10.28.0.34.7)
# Requirement already satisfied: PyYAML>=3.13 in ./name/lib/python3.12/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in ./name/lib/python3.12/site-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (24.1)
# Requirement already satisfied: soupsieve>1.2 in ./name/lib/python3.12/site-packages (from beautifulsoup4>=4.6.0->pycbc) (2.6)
# Requirement already satisfied: python-dateutil in ./name/lib/python3.12/site-packages (from lalsuite!=7.2->pycbc) (2.9.0.post0)
# Requirement already satisfied: pyOpenSSL in ./name/lib/python3.12/site-packages (from lscsoft-glue>=1.59.3->pycbc) (24.2.1)
# Requirement already satisfied: six in ./name/lib/python3.12/site-packages (from lscsoft-glue>=1.59.3->pycbc) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./name/lib/python3.12/site-packages (from Mako>=1.0.1->pycbc) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./name/lib/python3.12/site-packages (from matplotlib>=1.5.1->pycbc) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./name/lib/python3.12/site-packages (from matplotlib>=1.5.1->pycbc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./name/lib/python3.12/site-packages (from matplotlib>=1.5.1->pycbc) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./name/lib/python3.12/site-packages (from matplotlib>=1.5.1->pycbc) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./name/lib/python3.12/site-packages (from matplotlib>=1.5.1->pycbc) (3.2.0)
# Requirement already satisfied: pegasus-wms.common in ./name/lib/python3.12/site-packages (from pegasus-wms.api>=5.0.8->pycbc) (5.0.8)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in ./name/lib/python3.12/site-packages (from gwdatafind->pycbc) (1.1.1)
# Requirement already satisfied: cryptography>=2.3 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (43.0.3)
# Requirement already satisfied: requests>=2.14 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.32.3)
# Requirement already satisfied: safe-netrc>=1.0.0 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.0.1)
# Requirement already satisfied: scitokens>=1.7.0 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.8.1)
# Requirement already satisfied: cffi>=1.12 in ./name/lib/python3.12/site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2024.8.30)
# Requirement already satisfied: PyJWT>=1.6.1 in ./name/lib/python3.12/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.9.0)
# Requirement already satisfied: pycparser in ./name/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
! pip install lalsuite pycbc
# Out:
# Requirement already satisfied: lalsuite in ./name/lib/python3.12/site-packages (7.23)
# Requirement already satisfied: pycbc in ./name/lib/python3.12/site-packages (2.7.0)
# Requirement already satisfied: astropy in ./name/lib/python3.12/site-packages (from lalsuite) (6.1.4)
# Requirement already satisfied: ligo-segments in ./name/lib/python3.12/site-packages (from lalsuite) (1.4.0)
# Requirement already satisfied: lscsoft-glue in ./name/lib/python3.12/site-packages (from lalsuite) (4.0.0)
# Requirement already satisfied: matplotlib in ./name/lib/python3.12/site-packages (from lalsuite) (3.9.2)
# Requirement already satisfied: numpy>=1.19 in ./name/lib/python3.12/site-packages (from lalsuite) (2.1.2)
# Requirement already satisfied: python-dateutil in ./name/lib/python3.12/site-packages (from lalsuite) (2.9.0.post0)
# Requirement already satisfied: scipy in ./name/lib/python3.12/site-packages (from lalsuite) (1.14.1)
# Requirement already satisfied: cython>=0.29 in ./name/lib/python3.12/site-packages (from pycbc) (3.0.11)
# Requirement already satisfied: mpld3>=0.3 in ./name/lib/python3.12/site-packages (from pycbc) (0.5.10)
# Requirement already satisfied: pillow in ./name/lib/python3.12/site-packages (from pycbc) (11.0.0)
# Requirement already satisfied: h5py!=3.7.0,>=3.0.0 in ./name/lib/python3.12/site-packages (from pycbc) (3.12.1)
# Requirement already satisfied: jinja2 in ./name/lib/python3.12/site-packages (from pycbc) (3.1.4)
# Requirement already satisfied: Mako>=1.0.1 in ./name/lib/python3.12/site-packages (from pycbc) (1.3.6)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in ./name/lib/python3.12/site-packages (from pycbc) (4.12.3)
# Requirement already satisfied: tqdm in ./name/lib/python3.12/site-packages (from pycbc) (4.66.6)
# Requirement already satisfied: setuptools in ./name/lib/python3.12/site-packages (from pycbc) (75.3.0)
# Requirement already satisfied: gwdatafind in ./name/lib/python3.12/site-packages (from pycbc) (1.2.0)
# Requirement already satisfied: pegasus-wms.api>=5.0.8 in ./name/lib/python3.12/site-packages (from pycbc) (5.0.8)
# Requirement already satisfied: python-ligo-lw>=1.7.0 in ./name/lib/python3.12/site-packages (from pycbc) (1.8.3)
# Requirement already satisfied: pykerr in ./name/lib/python3.12/site-packages (from pycbc) (0.1.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in ./name/lib/python3.12/site-packages (from astropy->lalsuite) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.8.27.10.28.29 in ./name/lib/python3.12/site-packages (from astropy->lalsuite) (0.2024.10.28.0.34.7)
# Requirement already satisfied: PyYAML>=3.13 in ./name/lib/python3.12/site-packages (from astropy->lalsuite) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in ./name/lib/python3.12/site-packages (from astropy->lalsuite) (24.1)
# Requirement already satisfied: soupsieve>1.2 in ./name/lib/python3.12/site-packages (from beautifulsoup4>=4.6.0->pycbc) (2.6)
# Requirement already satisfied: pyOpenSSL in ./name/lib/python3.12/site-packages (from lscsoft-glue->lalsuite) (24.2.1)
# Requirement already satisfied: six in ./name/lib/python3.12/site-packages (from lscsoft-glue->lalsuite) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in ./name/lib/python3.12/site-packages (from Mako>=1.0.1->pycbc) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./name/lib/python3.12/site-packages (from matplotlib->lalsuite) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./name/lib/python3.12/site-packages (from matplotlib->lalsuite) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./name/lib/python3.12/site-packages (from matplotlib->lalsuite) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./name/lib/python3.12/site-packages (from matplotlib->lalsuite) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in ./name/lib/python3.12/site-packages (from matplotlib->lalsuite) (3.2.0)
# Requirement already satisfied: pegasus-wms.common in ./name/lib/python3.12/site-packages (from pegasus-wms.api>=5.0.8->pycbc) (5.0.8)
# Requirement already satisfied: igwn-auth-utils>=0.3.1 in ./name/lib/python3.12/site-packages (from gwdatafind->pycbc) (1.1.1)
# Requirement already satisfied: cryptography>=2.3 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (43.0.3)
# Requirement already satisfied: requests>=2.14 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.32.3)
# Requirement already satisfied: safe-netrc>=1.0.0 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.0.1)
# Requirement already satisfied: scitokens>=1.7.0 in ./name/lib/python3.12/site-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.8.1)
# Requirement already satisfied: cffi>=1.12 in ./name/lib/python3.12/site-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./name/lib/python3.12/site-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2024.8.30)
# Requirement already satisfied: PyJWT>=1.6.1 in ./name/lib/python3.12/site-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.9.0)
# Requirement already satisfied: pycparser in ./name/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.22)

# %%
from pycbc.detector import Detector, get_available_detectors
# We can list the available detectors. This gives their detector abbreviation
# along with a longer name. Note that some of these are not physical detectors
# but may be useful for testing or study purposes

for abv in get_available_detectors():
    d = Detector(abv)

    # Note that units are all in radians
    print("{} Latitude {} Longitude {}".format(abv,
                                                  d.latitude,
                                                  d.longitude))
for ifo1 in ['H1', 'L1', 'V1']:
    for ifo2 in ['H1', 'L1', 'V1']:
        dt = Detector(ifo1).light_travel_time_to_detector(Detector(ifo2))
        print("Direct Time from {} to {} is {} seconds".format(ifo1, ifo2, dt))
# Out:
# T1 Latitude 0.6226733602199997 Longitude 2.43536359469
# V0 Latitude 0.7615118398400004 Longitude 0.18333805213
# V1 Latitude 0.7615118398400004 Longitude 0.18333805213
# G1 Latitude 0.9118498275199999 Longitude 0.17116780435
# H2 Latitude 0.8107952638300001 Longitude -2.084056769170001
# H1 Latitude 0.5061454830783555 Longitude -1.6406094968746698
# L1 Latitude 0.8028514559173915 Longitude -2.181661564992913
# I1 Latitude 0.24841853020052615 Longitude 1.3340133249409993
# C1 Latitude 0.5963790054099999 Longitude -2.0617574453799996
# E1 Latitude 0.7615118398400004 Longitude 0.18333805213
# E2 Latitude 0.7629930799000002 Longitude 0.1840585887
# E3 Latitude 0.7627046325699999 Longitude 0.1819299673
# E0 Latitude 0.7627046325699999 Longitude 0.1819299673
# K1 Latitude 0.6355068497000002 Longitude 2.396441015
# U1 Latitude 0.0 Longitude 0.0
# A1 Latitude 0.53079879206 Longitude -1.5913706849599998
# O1 Latitude 0.79156499342 Longitude 0.20853775679
# X1 Latitude 0.81070543755 Longitude 0.10821041362
# N1 Latitude 0.7299645671 Longitude 0.22117684945999996
# B1 Latitude -0.5573418078 Longitude 2.02138216202
# T1 Latitude 0.6226733602199997 Longitude 2.43536359469
# V0 Latitude 0.7615118398400004 Longitude 0.18333805213
# V1 Latitude 0.7615118398400004 Longitude 0.18333805213
# G1 Latitude 0.9118498275199999 Longitude 0.17116780435
# H2 Latitude 0.8107952638300001 Longitude -2.084056769170001
# H1 Latitude 0.5061454830783555 Longitude -1.6406094968746698
# L1 Latitude 0.8028514559173915 Longitude -2.181661564992913
# I1 Latitude 0.24841853020052615 Longitude 1.3340133249409993
# C1 Latitude 0.5963790054099999 Longitude -2.0617574453799996
# E1 Latitude 0.7615118398400004 Longitude 0.18333805213
# E2 Latitude 0.7629930799000002 Longitude 0.1840585887
# E3 Latitude 0.7627046325699999 Longitude 0.1819299673
# E0 Latitude 0.7627046325699999 Longitude 0.1819299673
# K1 Latitude 0.6355068497000002 Longitude 2.396441015
# U1 Latitude 0.0 Longitude 0.0
# A1 Latitude 0.53079879206 Longitude -1.5913706849599998
# O1 Latitude 0.79156499342 Longitude 0.20853775679
# X1 Latitude 0.81070543755 Longitude 0.10821041362
# N1 Latitude 0.7299645671 Longitude 0.22117684945999996
# B1 Latitude -0.5573418078 Longitude 2.02138216202
# Direct Time from H1 to H1 is 0.0 seconds
# Direct Time from H1 to L1 is 0.01086639690018151 seconds
# Direct Time from H1 to V1 is 0.027340274104174053 seconds
# Direct Time from L1 to H1 is 0.01086639690018151 seconds
# Direct Time from L1 to L1 is 0.0 seconds
# Direct Time from L1 to V1 is 0.02798578496822353 seconds
# Direct Time from V1 to H1 is 0.027340274104174053 seconds
# Direct Time from V1 to L1 is 0.02798578496822353 seconds
# Direct Time from V1 to V1 is 0.0 seconds

# %%
# for single detector

import matplotlib.pyplot as plt
from pycbc.detector import Detector
import numpy as np

ra, dec = np.meshgrid(np.arange(0, np.pi * 2.0, .1), 
                      np.arange(-np.pi / 2.0, np.pi / 2.0, .1))
ra = ra.flatten()
dec = dec.flatten()

pol = 0
t=1e10  

for d in [Detector("L1"), Detector("H1"), Detector("K1"), Detector("V1")]:
    fp, fc = d.antenna_pattern(ra, dec, pol, time)

    plt.figure(figsize=[6, 16])
    ax = plt.subplot(111, projection="mollweide")
    ra[ra > np.pi] -= np.pi * 2.0
    scatter = ax.scatter(ra, dec, c=np.sqrt(fp**2.0 + fc**2.0), cmap='viridis')
    ax.grid(True)
    plt.title(f'Antenna Pattern Sensitivity for {d.name} (Mollweide Projection)', fontsize = 10)
    cbar = plt.colorbar(scatter, ax=ax, shrink=0.13, aspect=10, pad=0.05)
    cbar.set_label('Sensitivity',fontsize = 10)
    plt.show()

# %%
# all combinations of pairs of detectors

from itertools import combinations
detectors_list = [Detector("L1"), Detector("H1"), Detector("K1"), Detector("V1")]

detector_combinations = list(combinations(detectors_list, 2))

for pair in detector_combinations:
    sensitivity_combined = np.zeros(len(ra))  

    for d in pair:
        fp, fc = d.antenna_pattern(ra, dec, pol, time)
        sensitivity = np.sqrt(fp**2.0 + fc**2.0)      
        sensitivity_combined += sensitivity**2
        sensitivity_combined = np.sqrt(sensitivity_combined)

    ra[ra > np.pi] -= np.pi * 2.0
    plt.figure(figsize=[6, 16])
    ax = plt.subplot(111, projection="mollweide")
    scatter = ax.scatter(ra, dec, c=sensitivity_combined, cmap='viridis')
    ax.grid(True)
    title = f'Combined Sensitivity for {pair[0].name} and {pair[1].name} (Mollweide Projection)'
    plt.title(title, fontsize =10)
    cbar = plt.colorbar(scatter, ax=ax, shrink=0.13, aspect=10, pad=0.05)
    cbar.set_label('Combined Sensitivity')
    plt.show()

# %%
# all combinations of triplets of detectors

detectors_list = [Detector("L1"), Detector("H1"), Detector("K1"), Detector("V1")]
detector_combinations = list(combinations(detectors_list, 3))

for triplet in detector_combinations:
    sensitivity_combined = np.zeros(len(ra))  
    
    for d in triplet:
        fp, fc = d.antenna_pattern(ra, dec, pol, time)
        sensitivity = np.sqrt(fp**2.0 + fc**2.0)
        sensitivity_combined += sensitivity**2
        sensitivity_combined = np.sqrt(sensitivity_combined)
    # Adjust RA for the Mollweide projection
    ra[ra > np.pi] -= np.pi * 2.0
    plt.figure(figsize=[6, 16])
    ax = plt.subplot(111, projection="mollweide")
    scatter = ax.scatter(ra, dec, c=sensitivity_combined, cmap='viridis')
    ax.grid(True)
    title = f'Combined Sensitivity for {", ".join([d.name for d in triplet])} (Mollweide Projection)'
    plt.title(title,fontsize =10)
    cbar = plt.colorbar(scatter, ax=ax, shrink=0.13, aspect=10, pad=0.05)
    cbar.set_label('Combined Sensitivity')
    plt.show()

# %%
# for the combination of all four detectors

detectors_list = [Detector("L1"), Detector("H1"), Detector("K1"), Detector("V1")]
sensitivity_combined = np.zeros(len(ra))  

for d in detectors_list:
    fp, fc = d.antenna_pattern(ra, dec, pol, time)
    sensitivity = np.sqrt(fp**2.0 + fc**2.0)
    sensitivity_combined += sensitivity**2
    sensitivity_combined = np.sqrt(sensitivity_combined)
    
ra[ra > np.pi] -= np.pi * 2.0
plt.figure(figsize=[6, 16])
ax = plt.subplot(111, projection="mollweide")
scatter = ax.scatter(ra, dec, c=sensitivity_combined, cmap='viridis')
ax.grid(True)
plt.title(f'Combined Sensitivity for L1, H1, K1, and V1 (Mollweide Projection)',fontsize =10)
cbar = plt.colorbar(scatter, ax=ax, shrink=0.13, aspect=10, pad=0.05)
cbar.set_label('Combined Sensitivity')
plt.show()
